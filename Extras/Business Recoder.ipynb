# %%
import cloudscraper
import time
from bs4 import BeautifulSoup

BASE_URL = "https://www.brecorder.com/trends/kse100"

def get_scraper():
    return cloudscraper.create_scraper(
        browser={
            "browser": "chrome",
            "platform": "windows",
            "mobile": False
        }
    )

def scrape_brecorder_homepage(scraper):
    print(f"Scraping homepage: {BASE_URL}")
    response = scraper.get(BASE_URL, timeout=20)

    if response.status_code != 200:
        raise RuntimeError(f"HTTP {response.status_code}")

    soup = BeautifulSoup(response.text, "html.parser")

    articles = []

    for article in soup.select("article.story[data-id]"):
        title_tag = article.select_one("h2.story__title a")
        if not title_tag:
            continue

        time_el = article.select_one(
            ".story__time .timestamp--time"
        )

        articles.append({
            "id": article.get("data-id"),
            "title": title_tag.get_text(strip=True),
            "url": title_tag.get("href"),
            "published_at": time_el.get("title") if time_el else None
        })

    print(f"Found {len(articles)} articles.")
    return articles

# %%
def scrape_brecorder_article(scraper, url):
    print(f"Scraping article: {url}")
    try:
        response = scraper.get(url, timeout=20)

        if response.status_code != 200:
            print(f"Failed to fetch {url}: HTTP {response.status_code}")
            return None

        soup = BeautifulSoup(response.text, "html.parser")

        content = soup.select_one("div.story__content")
        if not content:
            print(f"No content found for {url}")
            return None

        # ❌ Remove unwanted elements
        for tag in content.select(
            "script, style, canvas, raw-html, div[id^='div-gpt-ad']"
        ):
            tag.decompose()

        paragraphs = []
        for p in content.find_all("p"):
            text = p.get_text(" ", strip=True)
            if text:
                paragraphs.append(text)

        article_text = "\n\n".join(paragraphs)

        return article_text
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# %%
# 1. Initialize Scraper
scraper = get_scraper()

# 2. Get Articles from Homepage
articles_data = scrape_brecorder_homepage(scraper)
# 3. Get Body for each article
for article in articles_data:
    # Construct full URL if relative
    article_url = article['url']
    if not article_url.startswith("http"):
        article_url = "https://www.brecorder.com" + article_url
        
        # Update the dictionary with full URL (optional but good practice)
    article['full_url'] = article_url

        # Scrape body
    body = scrape_brecorder_article(scraper, article_url)
    article['body'] = body

        # Optional: Sleep to prevent rate limiting
    time.sleep(1)

# 4. Result
print(f"\nSuccessfully scraped {len(articles_data)} articles with details.")
    
# Display sample of the first article
if articles_data:
    print("-" * 40)
    print("Sample Article Data:")
    print(f"Title: {articles_data[0]['title']}")
    print(f"Date: {articles_data[0]['published_at']}")
    print(f"ID: {articles_data[0]['id']}")
    print(f"URL: {articles_data[0]['full_url']}")
    print(f"Body Preview: {articles_data[0]['body'][:200]}..." if articles_data[0]['body'] else "No Body Content")
    print("-" * 40)
# Out:
# Scraping homepage: https://www.brecorder.com/trends/kse100
# Found 54 articles.
# Scraping article: https://www.brecorder.com/news/40399618/kse-100-hits-new-all-time-high-on-nearly-1500-point-rally
# Scraping article: https://www.brecorder.com/news/40399402/pakistan-stocks-expected-to-remain-best-performing-asset-class-in-2026-report
# Scraping article: https://www.brecorder.com/news/40395913/kse-100-index-gains-800-points-amid-bullish-momentum
# Scraping article: https://www.brecorder.com/news/40395543/selling-pressure-grips-bourse-kse-100-settles-nearly-1500-points-lower
# Scraping article: https://www.brecorder.com/news/40395332/kse-100-sheds-over-400-points-amid-late-profit-taking
# Scraping article: https://www.brecorder.com/news/40394747/buying-momentum-continues-kse-100-gains-over-1300-points
# Scraping article: https://www.brecorder.com/news/40394555/buying-rally-continues-kse-100-settles-with-nearly-2200-points-gain
# Scraping article: https://www.brecorder.com/news/40394335/buying-returns-kse-100-gains-nearly-1500-points
# Scraping article: https://www.brecorder.com/news/40394130/kse-100-index-closes-lower-as-profit-taking-persists
# Scraping article: https://www.brecorder.com/news/40393931/kse-100-closes-marginally-lower-after-volatile-trading
# Scraping article: https://www.brecorder.com/news/40393581/selling-returns-to-bourse-kse-100-settles-with-over-800-points-loss
# Scraping article: https://www.brecorder.com/news/40393161/buying-returns-to-bourse-kse-100-settles-with-nearly-1300-points-gain
# Scraping article: https://www.brecorder.com/news/40392980/selling-engulfs-bourse-kse-100-sheds-over-750-points
# Scraping article: https://www.brecorder.com/news/40392787/kse-100-sheds-nearly-250-points-amid-late-session-selling
# Scraping article: https://www.brecorder.com/news/40392416/stocks-remain-robust-kse-100-gains-nearly-1300-points
# Scraping article: https://www.brecorder.com/news/40392220/shares-at-kse-100-index-climb-2500-points-amid-imf-announcement
# Scraping article: https://www.brecorder.com/news/40391869/kse-100-falls-over-2-points-amid-renewed-political-security-uncertainty
# Failed to fetch https://www.brecorder.com/news/40391869/kse-100-falls-over-2-points-amid-renewed-political-security-uncertainty: HTTP 403
# Scraping article: https://www.brecorder.com/news/40391707/kse-100-could-hit-203000-by-2026-as-reforms-boost-sentiment-says-topline
# Failed to fetch https://www.brecorder.com/news/40391707/kse-100-could-hit-203000-by-2026-as-reforms-boost-sentiment-says-topline: HTTP 403
# Scraping article: https://www.brecorder.com/news/40391692/psx-extends-rally-as-kse-100-index-gains-over-1900-points
# Failed to fetch https://www.brecorder.com/news/40391692/psx-extends-rally-as-kse-100-index-gains-over-1900-points: HTTP 403
# Scraping article: https://www.brecorder.com/news/40391170/stocks-lose-momentum-as-kse-100-slips-nearly-500-points
# Scraping article: https://www.brecorder.com/news/40390963/psx-extends-losses-as-kse-100-loses-over-1-amid-global-market-rout
# Scraping article: https://www.brecorder.com/news/40390600/stocks-surge-kse-100-gains-nearly-1200-points
# Scraping article: https://www.brecorder.com/news/40390215/peace-talks-boost-sentiment-kse-100-gains-over-3-to-snap-7-day-losing-streak
# Scraping article: https://www.brecorder.com/news/40390011/selling-enters-seventh-day-as-kse-100-index-loses-over-1700-points
# Scraping article: https://www.brecorder.com/news/40389824/stocks-close-down-for-sixth-consecutive-session-as-kse-100-sheds-further-1600-points
# Failed to fetch https://www.brecorder.com/news/40389824/stocks-close-down-for-sixth-consecutive-session-as-kse-100-sheds-further-1600-points: HTTP 403
# Scraping article: https://www.brecorder.com/news/40389628/profit-taking-drags-kse-100-index-down-by-over-2000-points
# Scraping article: https://www.brecorder.com/news/40389039/selling-pressure-drags-psx-lower-kse-100-loses-nearly-1300-points
# Scraping article: https://www.brecorder.com/news/40388833/stocks-extend-losses-as-kse-100-closes-nearly-2000-points-down
# Scraping article: https://www.brecorder.com/news/40388660/kse-100-loses-nearly-800-points-amid-late-session-selling-pressure
# Scraping article: https://www.brecorder.com/news/40388474/bullish-sentiments-persist-kse-100-gains-over-1100-points
# Scraping article: https://www.brecorder.com/news/40403445/foreign-assistance-to-pakistan-hits-451-billion-in-first-half-of-2025-26
# Scraping article: https://www.brecorder.com/news/40403430/ke-dispute-gulf-investors-launch-2bn-arbitration-case-against-pakistan
# Scraping article: https://www.brecorder.com/news/40403453/davos-26-pakistan-to-enter-chinese-market-with-green-panda-bond-by-month-end-says-aurangzeb
# Scraping article: https://www.brecorder.com/news/40403249/gold-price-sets-new-record-high
# Failed to fetch https://www.brecorder.com/news/40403249/gold-price-sets-new-record-high: HTTP 403
# Scraping article: https://www.brecorder.com/news/40403494/davos-26-nestle-to-expand-operations-in-pakistan-with-60mn-investment
# Scraping article: https://www.brecorder.com/news/40403341/debut-ipo-of-2026-pak-qatar-general-takaful-share-price-hit-upper-limit-of-rs14
# Failed to fetch https://www.brecorder.com/news/40403341/debut-ipo-of-2026-pak-qatar-general-takaful-share-price-hit-upper-limit-of-rs14: HTTP 403
# Scraping article: https://www.brecorder.com/news/40402905/govt-will-save-as-much-as-17-billion-by-abandoning-procurement-of-expensive-electricity
# Failed to fetch https://www.brecorder.com/news/40402905/govt-will-save-as-much-as-17-billion-by-abandoning-procurement-of-expensive-electricity: HTTP 403
# Scraping article: https://www.brecorder.com/news/40403452/chinas-hisense-partners-air-link-subsidiary-eyes-investment-in-pakistan
# Scraping article: https://www.brecorder.com/news/40403280/davos-2026-uks-menzies-aviation-eyes-expansion-in-pakistan-amid-privatisation-push
# Scraping article: https://www.brecorder.com/news/40403296/gold-per-tola-gains-rs500
# Scraping article: https://www.brecorder.com/news/40403067/imf-lowers-pakistans-growth-outlook
# Scraping article: https://www.brecorder.com/news/40403258/pm-lashes-out-at-afghanistan-for-failure-to-tackle-terrorism
# Scraping article: https://www.brecorder.com/news/40403249/gold-price-sets-new-record-high
# Failed to fetch https://www.brecorder.com/news/40403249/gold-price-sets-new-record-high: HTTP 403
# Scraping article: https://www.brecorder.com/news/40403137/sazgar-enters-nev-segment-with-tank-500-hev-phev
# Scraping article: https://www.brecorder.com/news/40403257/world-bank-concerned-about-nepras-independence
# Scraping article: https://www.brecorder.com/news/40403293/successful-pia-privatisation-sends-strong-signal-to-global-investors-aurangzeb
# Scraping article: https://www.brecorder.com/news/40403067/imf-lowers-pakistans-growth-outlook
# Scraping article: https://www.brecorder.com/news/40403137/sazgar-enters-nev-segment-with-tank-500-hev-phev
# Failed to fetch https://www.brecorder.com/news/40403137/sazgar-enters-nev-segment-with-tank-500-hev-phev: HTTP 403
# Scraping article: https://www.brecorder.com/news/40403280/davos-2026-uks-menzies-aviation-eyes-expansion-in-pakistan-amid-privatisation-push
# Failed to fetch https://www.brecorder.com/news/40403280/davos-2026-uks-menzies-aviation-eyes-expansion-in-pakistan-amid-privatisation-push: HTTP 403
# Scraping article: https://www.brecorder.com/news/40403062/apple-samsung-google-new-customs-values-fixed-for-used-phones
# Failed to fetch https://www.brecorder.com/news/40403062/apple-samsung-google-new-customs-values-fixed-for-used-phones: HTTP 403
# Scraping article: https://www.brecorder.com/news/40402943/ubl-executes-pakistans-largest-ever-270mn-interest-rate-swap-with-jazz
# Scraping article: https://www.brecorder.com/news/40403249/gold-price-sets-new-record-high
# Scraping article: https://www.brecorder.com/news/40403445/foreign-assistance-to-pakistan-hits-451-billion-in-first-half-of-2025-26
# Scraping article: https://www.brecorder.com/news/40402961/govt-announces-schedule-for-public-holidays-in-2026
# Failed to fetch https://www.brecorder.com/news/40402961/govt-announces-schedule-for-public-holidays-in-2026: HTTP 403
#
# Successfully scraped 54 articles with details.
# ----------------------------------------
# Sample Article Data:
# Title: KSE-100 hits new all-time high on nearly 1,500-point rally
# Date: 2025-12-29T18:20:28+05:00
# ID: 40399618
# URL: https://www.brecorder.com/news/40399618/kse-100-hits-new-all-time-high-on-nearly-1500-point-rally
# Body Preview: Buying spree continued at the Pakistan Stock Exchange (PSX), with the benchmark KSE-100 Index closing at a new all-time high amid a gain of nearly 1,500 points on Monday.
#
# The benchmark index opened s...
# ----------------------------------------
